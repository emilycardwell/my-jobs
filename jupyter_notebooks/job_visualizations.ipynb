# %% [markdown]
# # Job Visualizations
#
# ***

# %% [markdown]
# ## Imports & Stored Data

# %%
import os
from py_files.visualization_functions import show_pair, show_cat_ref, \
    show_job_categories, show_initial_responses, show_apps_timeline, \
    show_subplt

from py_files.get_df_functions import get_responses, get_timeline_df, get_slim_cats

from py_files.data_functions import read_df

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Data Exploration

# %%
# data_path = os.getenv('DATA_PATH')
# file_path = data_path + '/job_data.json'
# jobs_df = read_df(file_path)
# jobs_df.head(3)

# %%
show_pair()

# %%
show_cat_ref()

# %% [markdown]
# ### Job Categories

# %%
show_job_categories()

# %% [markdown]
# ### Initial Responses by Date

# %%
show_initial_responses()

# %% [markdown]
# ### Timeline of Job Applications and Outcomes

# %%
show_apps_timeline()

# %% [markdown]
# # Subplotting

# %%
show_subplt()

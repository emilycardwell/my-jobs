# %% [markdown]
# # Job Visualizations
#
# ***

# %% [markdown]
# ## Imports & Stored Data

# %%
import os
from py_files.visualization_functions import show_pair, show_cat_ref, \
    show_job_categories, show_initial_responses, show_outcomes, \
    show_subplt, show_cat_compare, show_timeline

from py_files.get_df_functions import get_responses, get_timeline_df, \
    get_slim_cats, get_encoded_cols, get_ohe_df, get_location_df, get_prep_df, \
    get_outcomes

from py_files.data_functions import read_df

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Job Categories

# %%
show_job_categories()

# %% [markdown]
# ### Initial Responses by Date

# %%
show_initial_responses()

# %% [markdown]
# ### Final Outcomes by Date

# %%
show_outcomes()

# %%
get_outcomes()
# Out:
#    date_applied            final_outcome
# 0    2023-01-04      Immediate Rejection
# 1    2023-01-04              No Response
# 2    2023-01-04      Immediate Rejection
# 3    2023-01-04      Immediate Rejection
# 4    2023-01-04      Immediate Rejection
# 5    2023-01-04      Immediate Rejection
# 6    2023-01-07              No Response
# 7    2023-01-07  Rejected Post-Interview
# 8    2023-01-11      Immediate Rejection
# 9    2023-01-11              No Response
# 10   2023-01-11              No Response
# 11   2023-01-13      Immediate Rejection
# 12   2023-01-22      Immediate Rejection
# 13   2023-01-23            In Interviews
# 14   2023-01-26      Immediate Rejection
# 15   2023-02-09      Immediate Rejection
# 16   2023-02-09              No Response
# 17   2023-02-09              No Response
# 18   2023-02-09      Immediate Rejection
# 19   2023-02-14      Immediate Rejection
# 20   2023-02-14            In Interviews
# 21   2023-03-03              No Response
# 22   2023-03-06              No Response
# 23   2023-03-06              No Response
# 24   2023-03-07              No Response
# 25   2023-03-07              No Response

# %%
show_timeline()

# %% [markdown]
# ### Subplot

# %%
show_subplt()

# %% [markdown]
# ## Data Exploration

# %%
cat_cols = ['date_applied', 'job_cat', 'department', 'recruiter',
            'referral', 'method', 'location']

# %%
show_cat_compare(cat_cols)

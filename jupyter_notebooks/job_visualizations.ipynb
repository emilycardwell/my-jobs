# %% [markdown]
# # Job Visualizations
#
# ***

# %% [markdown]
# ## Imports & Stored Data

# %%
from py_files.visualization_functions import show_pair, show_cat_ref, \
    show_job_categories, show_initial_responses, show_outcomes, \
    show_cats, show_cat_compare, show_timeline, show_practice, show_work, \
    show_work_categories, show_work_projects, jobs_multiplot, work_prep_multiplot, \
    tree
from py_files.get_df_functions import get_location_df, get_slim_cats, \
    get_outcomes, get_work_df, get_timeline_df, get_responses, get_slim_prep_df, \
    get_init_responses, get_encoded_cols
from py_files.data_functions import verify_consolidate

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Timeline

# %%
show_timeline()

# %% [markdown]
# ### Location and Category

# %%
show_cats()

# %% [markdown]
# ### Final Outcomes and Features

# %%
tree()

# %%
show_cat_compare()

# %% [markdown]
# ### Multiplots

# %%
jobs_multiplot()

# %%
work_prep_multiplot()

# %% [markdown]
# ## Individual Visualizations

# %% [markdown]
# ### Job Categories

# %%
show_job_categories()

# %% [markdown]
# ### Initial Responses by Date

# %%
show_initial_responses()

# %% [markdown]
# ### Final Outcomes by Date

# %%
show_outcomes()

# %% [markdown]
# ### Practice and Work Visualizations

# %%
show_practice()

# %%
show_work()

# %%
show_work_categories()

# %%
show_work_projects()

# %% [markdown]
# ## Other

# %%
# verify_consolidate()

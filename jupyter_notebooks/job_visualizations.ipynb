# %% [markdown]
# # Job Visualizations
#
# ***

# %% [markdown]
# ## Imports & Stored Data

# %%
import os
from py_files.visualization_functions import show_pair, show_cat_ref, \
    show_job_categories, show_initial_responses, show_apps_timeline, \
    show_subplt

from py_files.get_df_functions import get_responses, get_timeline_df

from py_files.data_functions import read_df

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Data Exploration

# %%
# data_path = os.getenv('DATA_PATH')
# file_path = data_path + '/job_data.json'
# jobs_df = read_df(file_path)
# jobs_df.head(3)

# %%
show_pair()

# %%
show_cat_ref()

# %% [markdown]
# ### Job Categories

# %%
show_job_categories()

# %% [markdown]
# ### Initial Responses by Date

# %%
show_initial_responses()

# %% [markdown]
# ### Timeline of Job Applications and Outcomes

# %%
show_apps_timeline()
# Out:
# /Users/Emily/code/emilycardwell/my-jobs/py_files/visualization_functions.py:127: UserWarning: FixedFormatter should only be used together with FixedLocator
#   t_accum += feats[responses]

# %% [markdown]
# # Subplotting

# %%
show_subplt()

# %% [markdown]
# # Job Visualizations
#
# ***

# %% [markdown]
# ## Imports & Stored Data

# %%
from py_files.visualization_functions import show_pair, show_cat_ref, \
    show_job_categories, show_initial_responses, show_outcomes, \
    show_subplt, show_cat_compare, show_timeline, show_practice, show_work
from py_files.get_df_functions import get_location_df, get_slim_cats, \
    get_outcomes, get_work_df, get_timeline_df, get_responses, get_slim_prep_df
from py_files.data_functions import verify_consolidate

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Job Categories

# %%
show_job_categories()

# %% [markdown]
# ### Initial Responses by Date

# %%
show_initial_responses()

# %% [markdown]
# ### Final Outcomes by Date

# %%
show_outcomes()

# %%
show_practice()

# %%
show_work()

# %%
show_timeline()

# %% [markdown]
# ### Subplot

# %%
show_subplt()

# %% [markdown]
# ## Data Exploration

# %%
cat_cols = ['job_cat', 'location', 'department', 'recruiter',
            'referral', 'method', 'date_applied']

# %%
show_cat_compare()

# %%
verify_consolidate()
# Out:
# data added:
#    date_applied                 company_name
# 19   2023-05-03        Just Eat Takeaway.com  \
# 20   2023-05-08                Kolibri Games
# 37   2023-05-15                       Swarco
# 16   2023-05-22                        Eivee
# 17   2023-05-22                         Flix
# 21   2023-05-03        Just Eat Takeaway.com
# 22   2023-05-23                       Klarna
# 23   2023-05-22                       Klarna
# 24   2023-05-08                Kolibri Games
# 28   2023-05-23  MediaMarktSaturn Technology
# 29   2023-05-23  MediaMarktSaturn Technology
# 38   2023-05-15                 Raspberry Pi
# 39   2023-05-23                     Scontain
# 45   2023-05-23                    Stepstone
# 46   2023-05-15                       Strato
# 47   2023-05-22                       Ströer
# 48   2023-05-15                       Swarco
# 51   2023-05-22               Veeam Software
# 52   2023-05-22                        Veeva
# 54   2023-05-15                  WWF Germany
#
#                                    job_title           job_cat
# 19                  Junior System Specialist                IT  \
# 20                         Game Data Analyst      Data Analyst
# 37                 Cloud Operations Engineer    Cloud Engineer
# 16              Customer Operations Engineer  Support Engineer
# 17                             Data Engineer     Data Engineer
# 21                  Junior System Specialist                IT
# 22  Klarna Engineering Graduate Program 2023            Degree
# 23                Software Engineer - Python   Python Engineer
# 24                         Game Data Analyst      Data Analyst
# 28                   Junior Backend Engineer   Python Engineer
# 29                     Cloud System Engineer    Cloud Engineer
# 38                          Technical Writer  Technical Writer
# 39                        Software Developer   Python Engineer
# 45                   Search Backend Engineer   Python Engineer
# 46                    Junior DevOps Engineer   DevOps Engineer
# 47                             Data Engineer     Data Engineer
# 48                 Cloud Operations Engineer    Cloud Engineer
# 51                        Junior QA Engineer       QA Engineer
# 52        Data Analyst - Link for Key People      Data Analyst
# 54    Geospatial Analyst - Risk Filter Suite      Data Analyst
#
#                          department       location                  recruiter
# 19  Recruitment Information Systems         Berlin                        NaN  \
# 20                              NaN         Berlin                        NaN
# 37                              NaN         Berlin           Stephanie Danter
# 16                              NaN     Copenhagen  Maria Krysfeldt Rasmussen
# 17                 Network Planning         Berlin                        NaN
# 21  Recruitment Information Systems         Berlin                        NaN
# 22                              NaN         Berlin                        NaN
# 23                              NaN         Berlin                        NaN
# 24                              NaN         Berlin                        NaN
# 28                 Order Management         Berlin                        NaN
# 29                              NaN         Berlin                        NaN
# 38                              NaN  Cambridge, UK                        NaN
# 39                              NaN         Berlin                        NaN
# 45                              NaN         Berlin                        NaN
# 46                              NaN         Berlin                        NaN
# 47                              NaN         Berlin                        NaN
# 48                              NaN         Berlin           Stephanie Danter
# 51                              NaN         Berlin                        NaN
# 52              Link for Key People         Remote                        NaN
# 54                 Risk Filter Team         Berlin                        NaN
#
#                         referral     method
# 19  Yusuf Afyon, Carolin Janssen   referral  \
# 20                           NaN   linkedin
# 37                           NaN   linkedin
# 16                           NaN    website
# 17                           NaN    website
# 21  Yusuf Afyon, Carolin Janssen   referral
# 22                           NaN    website
# 23                           NaN  stepstone
# 24                           NaN   linkedin
# 28                           NaN    website
# 29                           NaN    website
# 38                           NaN    website
# 39                           NaN  stepstone
# 45                           NaN    website
# 46                           NaN  stepstone
# 47                           NaN  stepstone
# 48                           NaN   linkedin
# 51                           NaN   linkedin
# 52                           NaN    website
# 54                           NaN    website
#
#                                                   url date_init_resp
# 19  https://careers.justeattakeaway.com/global/en/...            NaN  \
# 20  https://jobs.lever.co/kolibrigames/028f1aae-99...            NaN
# 37  https://jobs.swarco.com/job/206923?referrer=SW...            NaN
# 16     https://www.linkedin.com/jobs/view/3604389528/            NaN
# 17     https://www.linkedin.com/jobs/view/3566660285/     2023-05-24
# 21  https://careers.justeattakeaway.com/global/en/...     2023-05-24
# 22  https://jobs.lever.co/klarna/8831e84f-1832-45d...            NaN
# 23  https://www.stepstone.de/stellenangebote--Soft...            NaN
# 24  https://jobs.lever.co/kolibrigames/028f1aae-99...     2023-05-22
# 28  https://careers.mediamarktsaturn.com/MediaMark...     2023-05-24
# 29  https://careers.mediamarktsaturn.com/MediaMark...            NaN
# 38                  https://www.raspberrypi.com/jobs/            NaN
# 39  https://www.stepstone.de/stellenangebote--Soft...            NaN
# 45  https://www.stepstone.de/stellenangebote--Sear...            NaN
# 46  https://www.stepstone.de/stellenangebote--Juni...     2023-05-22
# 47  https://www.stepstone.de/stellenangebote--Data...            NaN
# 48  https://jobs.swarco.com/job/206923?referrer=SW...     2023-05-24
# 51     https://www.linkedin.com/jobs/view/3608405269/     2023-05-24
# 52     https://www.linkedin.com/jobs/view/3554438267/     2023-05-24
# 54  https://wwf.onlyfy.jobs/job/cbw1znw91fibq3621z...            NaN
#
#    initial_response date_interview1 interview1_details date_interview2
# 19      No Response             NaN                NaN             NaN  \
# 20      No Response             NaN                NaN             NaN
# 37      No Response             NaN                NaN             NaN
# 16      No Response             NaN                NaN             NaN
# 17         Rejected             NaN                NaN             NaN
# 21         Rejected             NaN                NaN             NaN
# 22      No Response             NaN                NaN             NaN
# 23      No Response             NaN                NaN             NaN
# 24         Rejected             NaN                NaN             NaN
# 28         Rejected             NaN                NaN             NaN
# 29      No Response             NaN                NaN             NaN
# 38      No Response             NaN                NaN             NaN
# 39      No Response             NaN                NaN             NaN
# 45      No Response             NaN                NaN             NaN
# 46         Rejected             NaN                NaN             NaN
# 47      No Response             NaN                NaN             NaN
# 48         Rejected             NaN                NaN             NaN
# 51         Rejected             NaN                NaN             NaN
# 52         Rejected             NaN                NaN             NaN
# 54      No Response             NaN                NaN             NaN
#
#    interview2_details date_interview3 interview3_details        final_outcome
# 19                NaN             NaN                NaN          No Response  \
# 20                NaN             NaN                NaN          No Response
# 37                NaN             NaN                NaN          No Response
# 16                NaN             NaN                NaN          No Response
# 17                NaN             NaN                NaN  Immediate Rejection
# 21                NaN             NaN                NaN  Immediate Rejection
# 22                NaN             NaN                NaN          No Response
# 23                NaN             NaN                NaN          No Response
# 24                NaN             NaN                NaN  Immediate Rejection
# 28                NaN             NaN                NaN  Immediate Rejection
# 29                NaN             NaN                NaN          No Response
# 38                NaN             NaN                NaN          No Response
# 39                NaN             NaN                NaN          No Response
# 45                NaN             NaN                NaN          No Response
# 46                NaN             NaN                NaN  Immediate Rejection
# 47                NaN             NaN                NaN          No Response
# 48                NaN             NaN                NaN  Immediate Rejection
# 51                NaN             NaN                NaN  Immediate Rejection
# 52                NaN             NaN                NaN  Immediate Rejection
# 54                NaN             NaN                NaN          No Response
#
#    feedback
# 19      NaN
# 20      NaN
# 37      NaN
# 16      NaN
# 17      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 28      NaN
# 29      NaN
# 38      NaN
# 39      NaN
# 45      NaN
# 46      NaN
# 47      NaN
# 48      NaN
# 51      NaN
# 52      NaN
# 54      NaN
# data added:
#          job          category        date
# 133     Jobs          Research  2023-05-23
# 134  my-jobs  Data Engineering  2023-05-23
# data added:
#              site                   submissions date_completed        date
# 0     hacker_rank                Print Function     2023-01-05         NaN
# 1     hacker_rank                   Capitalize!     2023-01-05         NaN
# 2     hacker_rank               The Minion Game     2023-01-05         NaN
# 3     hacker_rank              Merge the Tools!     2023-01-05         NaN
# 4     hacker_rank                    Word Order     2023-01-05         NaN
# ..            ...                           ...            ...         ...
# 73       codility           ArrayInversionCount            NaN  2023-03-02
# 74  geeks_4_geeks                 Binary Search            NaN  2023-03-10
# 75    hacker_rank  Python (Basic) Certification            NaN  2023-03-10
# 76    hacker_rank     SQL (Basic) Certification            NaN  2023-03-10
# 77  geeks_4_geeks       Maximum Triplet product            NaN  2023-03-10
#
# [156 rows x 4 columns]

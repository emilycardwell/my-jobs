# %% [markdown]
# # Job Visualizations
#
# ***

# %% [markdown]
# ## Imports & Stored Data

# %%
import os
from py_files.visualization_functions import show_pair, show_cat_ref, \
    show_job_categories, show_initial_responses, show_outcomes, \
    show_subplt, show_cat_compare, show_timeline, show_practice
    
from py_files.get_df_functions import get_responses, get_outcomes, get_slim_cats, \
    get_location_df, get_encoded_cols

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Job Categories

# %%
show_job_categories()

# %% [markdown]
# ### Initial Responses by Date

# %%
show_initial_responses()

# %% [markdown]
# ### Final Outcomes by Date

# %%
show_outcomes()

# %%
show_practice()

# %%
show_timeline()

# %% [markdown]
# ### Subplot

# %%
show_subplt()

# %% [markdown]
# ## Data Exploration

# %%
cat_cols = ['job_cat', 'location', 'department', 'recruiter',
            'referral', 'method', 'date_applied']

# %%
show_cat_compare()
